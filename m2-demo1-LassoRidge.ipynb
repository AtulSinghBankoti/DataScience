# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 0.25.1

# %%
#downloaded data from: https://archive.ics.uci.edu/ml/machine-learning-databases/autos/

auto_data=pd.read_csv('imports-85.data',names=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels","engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders","engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm ","city-mpg","highway-mpg","price"],
                      sep=r'\s*,\s*', engine='python')
auto_data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two    hatchback          rwd           front        94.5  ...
# 3           four        sedan          fwd           front        99.8  ...
# 4           four        sedan          4wd           front        99.4  ...
# ..           ...          ...          ...             ...         ...  ...
# 200         four        sedan          rwd           front       109.1  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            152         mpfi  2.68    3.47               9.0        154
# 3            109         mpfi  3.19    3.40              10.0        102
# 4            136         mpfi  3.19    3.40               8.0        115
# ..           ...          ...   ...     ...               ...        ...
# 200          141         mpfi  3.78    3.15               9.5        114
# 201          141         mpfi  3.78    3.15               8.7        160
# 202          173         mpfi  3.58    2.87               8.8        134
# 203          145          idi  3.01    3.40              23.0        106
# 204          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm  city-mpg highway-mpg  price
# 0         5000       21          27  13495
# 1         5000       21          27  16500
# 2         5000       19          26  16500
# 3         5500       24          30  13950
# 4         5500       18          22  17450
# ..         ...      ...         ...    ...
# 200       5400       23          28  16845
# 201       5300       19          25  19045
# 202       5500       18          23  21485
# 203       4800       26          27  22470
# 204       5400       19          25  22625
#
# [205 rows x 26 columns]

# %%
import numpy as np

auto_data=auto_data.replace('?', np.nan)
auto_data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
#    fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68               9.0        111       5000       21
# 1         mpfi  3.47    2.68               9.0        111       5000       21
# 2         mpfi  2.68    3.47               9.0        154       5000       19
# 3         mpfi  3.19    3.40              10.0        102       5500       24
# 4         mpfi  3.19    3.40               8.0        115       5500       18
#
#   highway-mpg  price
# 0          27  13495
# 1          27  16500
# 2          26  16500
# 3          30  13950
# 4          22  17450
#
# [5 rows x 26 columns]

# %%
auto_data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# min    1488.000000    61.000000           7.000000   13.000000    16.000000
# 25%    2145.000000    97.000000           8.600000   19.000000    25.000000
# 50%    2414.000000   120.000000           9.000000   24.000000    30.000000
# 75%    2935.000000   141.000000           9.400000   30.000000    34.000000
# max    4066.000000   326.000000          23.000000   49.000000    54.000000

# %%
auto_data.describe(include='all')
# Out:
#          symboling normalized-losses    make fuel-type aspiration  \
# count   205.000000               164     205       205        205
# unique         NaN                51      22         2          2
# top            NaN               161  toyota       gas        std
# freq           NaN                11      32       185        168
# mean      0.834146               NaN     NaN       NaN        NaN
# std       1.245307               NaN     NaN       NaN        NaN
# min      -2.000000               NaN     NaN       NaN        NaN
# 25%       0.000000               NaN     NaN       NaN        NaN
# 50%       1.000000               NaN     NaN       NaN        NaN
# 75%       2.000000               NaN     NaN       NaN        NaN
# max       3.000000               NaN     NaN       NaN        NaN
#
#        num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# count           203        205          205             205  205.000000  ...
# unique            2          5            3               2         NaN  ...
# top            four      sedan          fwd           front         NaN  ...
# freq            114         96          120             202         NaN  ...
# mean            NaN        NaN          NaN             NaN   98.756585  ...
# std             NaN        NaN          NaN             NaN    6.021776  ...
# min             NaN        NaN          NaN             NaN   86.600000  ...
# 25%             NaN        NaN          NaN             NaN   94.500000  ...
# 50%             NaN        NaN          NaN             NaN   97.000000  ...
# 75%             NaN        NaN          NaN             NaN  102.400000  ...
# max             NaN        NaN          NaN             NaN  120.900000  ...
#
#         engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# count    205.000000          205   201     201        205.000000        203
# unique          NaN            8    38      36               NaN         59
# top             NaN         mpfi  3.62    3.40               NaN         68
# freq            NaN           94    23      20               NaN         19
# mean     126.907317          NaN   NaN     NaN         10.142537        NaN
# std       41.642693          NaN   NaN     NaN          3.972040        NaN
# min       61.000000          NaN   NaN     NaN          7.000000        NaN
# 25%       97.000000          NaN   NaN     NaN          8.600000        NaN
# 50%      120.000000          NaN   NaN     NaN          9.000000        NaN
# 75%      141.000000          NaN   NaN     NaN          9.400000        NaN
# max      326.000000          NaN   NaN     NaN         23.000000        NaN
#
#         peak-rpm     city-mpg highway-mpg price
# count         203  205.000000  205.000000   201
# unique         23         NaN         NaN   186
# top          5500         NaN         NaN  5572
# freq           37         NaN         NaN     2
# mean          NaN   25.219512   30.751220   NaN
# std           NaN    6.542142    6.886443   NaN
# min           NaN   13.000000   16.000000   NaN
# 25%           NaN   19.000000   25.000000   NaN
# 50%           NaN   24.000000   30.000000   NaN
# 75%           NaN   30.000000   34.000000   NaN
# max           NaN   49.000000   54.000000   NaN
#
# [11 rows x 26 columns]

# %%
auto_data=auto_data.dropna()
auto_data
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 3            2               164   audi       gas        std         four
# 4            2               164   audi       gas        std         four
# 6            1               158   audi       gas        std         four
# 8            1               158   audi       gas      turbo         four
# 10           2               192    bmw       gas        std          two
# ..         ...               ...    ...       ...        ...          ...
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 10       sedan          rwd           front       101.2  ...          108
# ..         ...          ...             ...         ...  ...          ...
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm   \
# 3           mpfi  3.19    3.40              10.0        102       5500
# 4           mpfi  3.19    3.40               8.0        115       5500
# 6           mpfi  3.19    3.40               8.5        110       5500
# 8           mpfi  3.13    3.40               8.3        140       5500
# 10          mpfi  3.50    2.80               8.8        101       5800
# ..           ...   ...     ...               ...        ...        ...
# 200         mpfi  3.78    3.15               9.5        114       5400
# 201         mpfi  3.78    3.15               8.7        160       5300
# 202         mpfi  3.58    2.87               8.8        134       5500
# 203          idi  3.01    3.40              23.0        106       4800
# 204         mpfi  3.78    3.15               9.5        114       5400
#
#     city-mpg highway-mpg  price
# 3         24          30  13950
# 4         18          22  17450
# 6         19          25  17710
# 8         17          20  23875
# 10        23          29  16430
# ..       ...         ...    ...
# 200       23          28  16845
# 201       19          25  19045
# 202       18          23  21485
# 203       26          27  22470
# 204       19          25  22625
#
# [159 rows x 26 columns]

# %%
auto_data['price'].describe()
# Out:
# count      159
# unique     145
# top       7295
# freq         2
# Name: price, dtype: object

# %%
auto_data['price']=pd.to_numeric(auto_data['price'],
                                 errors='coerce')

# %%
auto_data['price'].describe()
# Out:
# count      159.000000
# mean     11445.729560
# std       5877.856195
# min       5118.000000
# 25%       7372.000000
# 50%       9233.000000
# 75%      14719.500000
# max      35056.000000
# Name: price, dtype: float64

# %%
auto_data=auto_data.drop('normalized-losses',axis=1)
auto_data.head()
# Out:
#     symboling  make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 3           2  audi       gas        std         four      sedan          fwd
# 4           2  audi       gas        std         four      sedan          4wd
# 6           1  audi       gas        std         four      sedan          fwd
# 8           1  audi       gas      turbo         four      sedan          fwd
# 10          2   bmw       gas        std          two      sedan          rwd
#
#    engine-location  wheel-base  length  ...  engine-size  fuel-system  bore  \
# 3            front        99.8   176.6  ...          109         mpfi  3.19
# 4            front        99.4   176.6  ...          136         mpfi  3.19
# 6            front       105.8   192.7  ...          136         mpfi  3.19
# 8            front       105.8   192.7  ...          131         mpfi  3.13
# 10           front       101.2   176.8  ...          108         mpfi  3.50
#
#    stroke compression-ratio  horsepower peak-rpm  city-mpg highway-mpg  price
# 3    3.40              10.0         102      5500       24          30  13950
# 4    3.40               8.0         115      5500       18          22  17450
# 6    3.40               8.5         110      5500       19          25  17710
# 8    3.40               8.3         140      5500       17          20  23875
# 10   2.80               8.8         101      5800       23          29  16430
#
# [5 rows x 25 columns]

# %%
auto_data['horsepower'].describe()
# Out:
# count     159
# unique     48
# top        68
# freq       18
# Name: horsepower, dtype: object

# %%
auto_data['horsepower']=pd.to_numeric(auto_data['horsepower'],errors='coerce')

# %%
auto_data['horsepower'].describe()
# Out:
# count    159.000000
# mean      95.836478
# std       30.718583
# min       48.000000
# 25%       69.000000
# 50%       88.000000
# 75%      114.000000
# max      200.000000
# Name: horsepower, dtype: float64

# %%
auto_data['num-of-cylinders']
# Out:
# 3      four
# 4      five
# 6      five
# 8      five
# 10     four
#        ...
# 200    four
# 201    four
# 202     six
# 203     six
# 204    four
# Name: num-of-cylinders, Length: 159, dtype: object

# %%
cylinders_dict = {'two':2,'three':3,'four':4,'five':5,
                 "six":6,"eight":8,"twelve":12}

auto_data['num-of-cylinders'].replace(cylinders_dict,
                                      inplace=True)

auto_data.head()
# Out:
#     symboling  make fuel-type aspiration num-of-doors body-style drive-wheels  \
# 3           2  audi       gas        std         four      sedan          fwd
# 4           2  audi       gas        std         four      sedan          4wd
# 6           1  audi       gas        std         four      sedan          fwd
# 8           1  audi       gas      turbo         four      sedan          fwd
# 10          2   bmw       gas        std          two      sedan          rwd
#
#    engine-location  wheel-base  length  ...  engine-size  fuel-system  bore  \
# 3            front        99.8   176.6  ...          109         mpfi  3.19
# 4            front        99.4   176.6  ...          136         mpfi  3.19
# 6            front       105.8   192.7  ...          136         mpfi  3.19
# 8            front       105.8   192.7  ...          131         mpfi  3.13
# 10           front       101.2   176.8  ...          108         mpfi  3.50
#
#    stroke compression-ratio  horsepower peak-rpm  city-mpg highway-mpg  price
# 3    3.40              10.0         102      5500       24          30  13950
# 4    3.40               8.0         115      5500       18          22  17450
# 6    3.40               8.5         110      5500       19          25  17710
# 8    3.40               8.3         140      5500       17          20  23875
# 10   2.80               8.8         101      5800       23          29  16430
#
# [5 rows x 25 columns]

# %%
auto_data=pd.get_dummies(auto_data, columns=[
    'make',
    'fuel-type',
    'aspiration',
    'num-of-doors',
    'body-style',
    'drive-wheels',
    'engine-location',
    'engine-type',
    'fuel-system'])

auto_data.head()
# Out:
#     symboling  wheel-base  length  width  height  curb-weight  \
# 3           2        99.8   176.6   66.2    54.3         2337
# 4           2        99.4   176.6   66.4    54.3         2824
# 6           1       105.8   192.7   71.4    55.7         2844
# 8           1       105.8   192.7   71.4    55.9         3086
# 10          2       101.2   176.8   64.8    54.3         2395
#
#    num-of-cylinders  engine-size  bore stroke  ...  engine-type_l  \
# 3                 4          109  3.19   3.40  ...              0
# 4                 5          136  3.19   3.40  ...              0
# 6                 5          136  3.19   3.40  ...              0
# 8                 5          131  3.13   3.40  ...              0
# 10                4          108  3.50   2.80  ...              0
#
#     engine-type_ohc engine-type_ohcf  engine-type_ohcv  fuel-system_1bbl  \
# 3                 1                0                 0                 0
# 4                 1                0                 0                 0
# 6                 1                0                 0                 0
# 8                 1                0                 0                 0
# 10                1                0                 0                 0
#
#     fuel-system_2bbl  fuel-system_idi  fuel-system_mfi  fuel-system_mpfi  \
# 3                  0                0                0                 1
# 4                  0                0                0                 1
# 6                  0                0                0                 1
# 8                  0                0                0                 1
# 10                 0                0                0                 1
#
#     fuel-system_spdi
# 3                  0
# 4                  0
# 6                  0
# 8                  0
# 10                 0
#
# [5 rows x 60 columns]

# %%
auto_data=auto_data.dropna()
auto_data
# Out:
#      symboling  wheel-base  length  width  height  curb-weight  \
# 3            2        99.8   176.6   66.2    54.3         2337
# 4            2        99.4   176.6   66.4    54.3         2824
# 6            1       105.8   192.7   71.4    55.7         2844
# 8            1       105.8   192.7   71.4    55.9         3086
# 10           2       101.2   176.8   64.8    54.3         2395
# ..         ...         ...     ...    ...     ...          ...
# 200         -1       109.1   188.8   68.9    55.5         2952
# 201         -1       109.1   188.8   68.8    55.5         3049
# 202         -1       109.1   188.8   68.9    55.5         3012
# 203         -1       109.1   188.8   68.9    55.5         3217
# 204         -1       109.1   188.8   68.9    55.5         3062
#
#     num-of-cylinders  engine-size  bore stroke  ...  engine-type_l  \
# 3                  4          109  3.19   3.40  ...              0
# 4                  5          136  3.19   3.40  ...              0
# 6                  5          136  3.19   3.40  ...              0
# 8                  5          131  3.13   3.40  ...              0
# 10                 4          108  3.50   2.80  ...              0
# ..               ...          ...   ...    ...  ...            ...
# 200                4          141  3.78   3.15  ...              0
# 201                4          141  3.78   3.15  ...              0
# 202                6          173  3.58   2.87  ...              0
# 203                6          145  3.01   3.40  ...              0
# 204                4          141  3.78   3.15  ...              0
#
#      engine-type_ohc engine-type_ohcf  engine-type_ohcv  fuel-system_1bbl  \
# 3                  1                0                 0                 0
# 4                  1                0                 0                 0
# 6                  1                0                 0                 0
# 8                  1                0                 0                 0
# 10                 1                0                 0                 0
# ..               ...              ...               ...               ...
# 200                1                0                 0                 0
# 201                1                0                 0                 0
# 202                0                0                 1                 0
# 203                1                0                 0                 0
# 204                1                0                 0                 0
#
#      fuel-system_2bbl  fuel-system_idi  fuel-system_mfi  fuel-system_mpfi  \
# 3                   0                0                0                 1
# 4                   0                0                0                 1
# 6                   0                0                0                 1
# 8                   0                0                0                 1
# 10                  0                0                0                 1
# ..                ...              ...              ...               ...
# 200                 0                0                0                 1
# 201                 0                0                0                 1
# 202                 0                0                0                 1
# 203                 0                1                0                 0
# 204                 0                0                0                 1
#
#      fuel-system_spdi
# 3                   0
# 4                   0
# 6                   0
# 8                   0
# 10                  0
# ..                ...
# 200                 0
# 201                 0
# 202                 0
# 203                 0
# 204                 0
#
# [159 rows x 60 columns]

# %%
auto_data[auto_data.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [symboling, wheel-base, length, width, height, curb-weight, num-of-cylinders, engine-size, bore, stroke, compression-ratio, horsepower, peak-rpm , city-mpg, highway-mpg, price, make_audi, make_bmw, make_chevrolet, make_dodge, make_honda, make_jaguar, make_mazda, make_mercedes-benz, make_mitsubishi, make_nissan, make_peugot, make_plymouth, make_porsche, make_saab, make_subaru, make_toyota, make_volkswagen, make_volvo, fuel-type_diesel, fuel-type_gas, aspiration_std, aspiration_turbo, num-of-doors_four, num-of-doors_two, body-style_convertible, body-style_hardtop, body-style_hatchback, body-style_sedan, body-style_wagon, drive-wheels_4wd, drive-wheels_fwd, drive-wheels_rwd, engine-location_front, engine-type_dohc, engine-type_l, engine-type_ohc, engine-type_ohcf, engine-type_ohcv, fuel-system_1bbl, fuel-system_2bbl, fuel-system_idi, fuel-system_mfi, fuel-system_mpfi, fuel-system_spdi]
# Index: []
#
# [0 rows x 60 columns]

# %%
from sklearn.model_selection import train_test_split

X = auto_data.drop('price', axis=1)

#Taking the labels (price)
Y = auto_data['price']

# Spliting into 80% for training set and 20% for testing set so we can see our accuracy

X_train, x_test, Y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()
linear_model.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear_model.score(X_train, Y_train)
# Out:
# 0.9737447559609992

# %%
linear_model.coef_
# Out:
# array([-6.01334519e+01,  2.64366498e+02, -8.23469092e+01,  2.41639703e+02,
#        -2.97313497e+02,  4.34119997e+00,  5.58180628e+02,  3.18250227e+00,
#        -1.50862705e+03, -4.33727685e+02, -3.30926028e+02, -2.70197671e+01,
#        -5.37516018e-01, -2.00223993e+02,  6.68851102e+01,  2.92675447e+03,
#         3.03610482e+03, -1.56561502e+03, -3.25262042e+03,  9.35273110e+02,
#         5.35785563e+03, -1.28726268e+03,  6.10725106e+03, -3.29540060e+03,
#        -6.55825887e+02, -2.31979463e+03, -2.61626100e+03, -1.36424205e-12,
#         2.32325726e+03, -9.68311641e+02, -3.19127702e+03, -1.25794217e+03,
#        -2.76185270e+02,  1.33610324e+03, -1.33610324e+03, -1.06899562e+03,
#         1.06899562e+03,  5.24853650e+02, -5.24853650e+02,  4.98637422e+03,
#        -1.31098744e+03, -1.11417838e+03, -1.21246181e+03, -1.34874657e+03,
#        -9.45636324e+02, -9.43738496e+02,  1.88937482e+03,  0.00000000e+00,
#         2.06400588e+03, -2.31979463e+03,  4.78665849e+02, -9.68311641e+02,
#         7.45434540e+02, -2.28358900e+03, -2.77423519e+02,  1.33610324e+03,
#         1.59254357e+03,  3.58641359e+02, -7.26275649e+02])

# %%
predictors = X_train.columns
coef = pd.Series(linear_model.coef_, predictors).sort_values()

print(coef)
# Out:
# make_mitsubishi          -3.295401e+03
# make_dodge               -3.252620e+03
# make_toyota              -3.191277e+03
# make_plymouth            -2.616261e+03
# engine-type_l            -2.319795e+03
# make_peugot              -2.319795e+03
# fuel-system_1bbl         -2.283589e+03
# make_chevrolet           -1.565615e+03
# bore                     -1.508627e+03
# body-style_wagon         -1.348747e+03
# fuel-type_gas            -1.336103e+03
# body-style_hardtop       -1.310987e+03
# make_mazda               -1.287263e+03
# make_volkswagen          -1.257942e+03
# body-style_sedan         -1.212462e+03
# body-style_hatchback     -1.114178e+03
# aspiration_std           -1.068996e+03
# engine-type_ohcf         -9.683116e+02
# make_subaru              -9.683116e+02
# drive-wheels_4wd         -9.456363e+02
# drive-wheels_fwd         -9.437385e+02
# fuel-system_spdi         -7.262756e+02
# make_nissan              -6.558259e+02
# num-of-doors_two         -5.248537e+02
# stroke                   -4.337277e+02
# compression-ratio        -3.309260e+02
# height                   -2.973135e+02
# fuel-system_2bbl         -2.774235e+02
# make_volvo               -2.761853e+02
# city-mpg                 -2.002240e+02
# length                   -8.234691e+01
# symboling                -6.013345e+01
# horsepower               -2.701977e+01
# peak-rpm                 -5.375160e-01
# make_porsche             -1.364242e-12
# engine-location_front     0.000000e+00
# engine-size               3.182502e+00
# curb-weight               4.341200e+00
# highway-mpg               6.688511e+01
# width                     2.416397e+02
# wheel-base                2.643665e+02
# fuel-system_mpfi          3.586414e+02
# engine-type_ohc           4.786658e+02
# num-of-doors_four         5.248537e+02
# num-of-cylinders          5.581806e+02
# engine-type_ohcv          7.454345e+02
# make_honda                9.352731e+02
# aspiration_turbo          1.068996e+03
# fuel-type_diesel          1.336103e+03
# fuel-system_idi           1.336103e+03
# fuel-system_mfi           1.592544e+03
# drive-wheels_rwd          1.889375e+03
# engine-type_dohc          2.064006e+03
# make_saab                 2.323257e+03
# make_audi                 2.926754e+03
# make_bmw                  3.036105e+03
# body-style_convertible    4.986374e+03
# make_jaguar               5.357856e+03
# make_mercedes-benz        6.107251e+03
# dtype: float64

# %%
y_predict = linear_model.predict(x_test)

# %%
# %pylab inline

pylab.rcParams['figure.figsize']=(15, 6)

plt.plot(y_predict, label='Predicted')
plt.plot(y_test.values, label='Actual')
plt.ylabel('Price')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r_square = linear_model.score(x_test, y_test)
r_square
# Out:
# 0.8784707425068418

# %%
from sklearn.metrics import mean_squared_error

linear_model_mse = mean_squared_error(y_predict, y_test)

linear_model_mse
# Out:
# 4599760.084039227

# %%
import math

math.sqrt(linear_model_mse)
# Out:
# 2144.7051275266786

# %%
#Lasso demo

from sklearn.linear_model import Lasso

lasso_model = Lasso(alpha=5, normalize=True)
lasso_model.fit(X_train, Y_train)
# Out:
# Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000, normalize=True,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
#       tol=0.0001, warm_start=False)

# %%
lasso_model.score(X_train, Y_train)
# Out:
# 0.9719525400666299

# %%
coef = pd.Series(lasso_model.coef_, predictors).sort_values()
print(coef)
# Out:
# aspiration_std           -1.927537e+03
# engine-type_l            -1.709585e+03
# make_mitsubishi          -1.655682e+03
# make_dodge               -1.384418e+03
# fuel-system_1bbl         -1.271565e+03
# make_toyota              -1.184335e+03
# bore                     -1.099405e+03
# make_plymouth            -9.807208e+02
# fuel-system_spdi         -6.245953e+02
# engine-type_ohcf         -4.518470e+02
# body-style_hardtop       -3.614015e+02
# make_peugot              -3.559061e+02
# body-style_wagon         -2.924111e+02
# stroke                   -2.145079e+02
# height                   -2.093415e+02
# make_subaru              -2.034465e+02
# drive-wheels_fwd         -1.735258e+02
# city-mpg                 -1.245727e+02
# make_chevrolet           -5.916272e+01
# length                   -3.980078e+01
# peak-rpm                 -1.346547e-01
# symboling                -0.000000e+00
# drive-wheels_4wd          0.000000e+00
# body-style_sedan         -0.000000e+00
# num-of-doors_two         -0.000000e+00
# engine-size               0.000000e+00
# fuel-type_gas            -0.000000e+00
# compression-ratio         0.000000e+00
# make_volkswagen          -0.000000e+00
# engine-location_front     0.000000e+00
# make_porsche              0.000000e+00
# horsepower               -0.000000e+00
# highway-mpg               0.000000e+00
# engine-type_ohcv         -0.000000e+00
# fuel-system_2bbl         -0.000000e+00
# aspiration_turbo          5.631224e-11
# fuel-system_idi           3.487806e-01
# curb-weight               3.280851e+00
# body-style_hatchback      2.529945e+01
# engine-type_ohc           1.369004e+02
# engine-type_dohc          2.087746e+02
# width                     2.091955e+02
# wheel-base                2.155820e+02
# fuel-type_diesel          2.319939e+02
# fuel-system_mpfi          2.851704e+02
# make_mazda                3.007362e+02
# make_nissan               4.030225e+02
# num-of-cylinders          7.042503e+02
# num-of-doors_four         7.732403e+02
# fuel-system_mfi           8.314641e+02
# make_volvo                1.207280e+03
# make_honda                1.407766e+03
# drive-wheels_rwd          2.110094e+03
# make_saab                 3.011206e+03
# make_audi                 3.786284e+03
# make_bmw                  4.560917e+03
# body-style_convertible    5.727850e+03
# make_mercedes-benz        8.293403e+03
# make_jaguar               8.522939e+03
# dtype: float64

# %%
y_predict=lasso_model.predict(x_test)

# %%
pylab.rcParams['figure.figsize']=(15, 6)

plt.plot(y_predict, label='Predicted')
plt.plot(y_test.values, label='Actual')
plt.ylabel('Price')

plt.legend()
plt.show()

# %%
r_square = lasso_model.score(x_test, y_test)
r_square
# Out:
# 0.8682157043565671

# %%
lasso_nodel_mse = mean_squared_error(y_predict, y_test)
math.sqrt(lasso_nodel_mse)
# Out:
# 2233.361358341302

# %%
#Ridge demo

from sklearn.linear_model import Ridge

ridge_model = Ridge(alpha=1, normalize=True)
ridge_model.fit(X_train, Y_train)
# Out:
# Ridge(alpha=1, copy_X=True, fit_intercept=True, max_iter=None, normalize=True,
#       random_state=None, solver='auto', tol=0.001)

# %%
ridge_model.score(X_train, Y_train)
# Out:
# 0.9308160978593685

# %%
coef = pd.Series(ridge_model.coef_, predictors).sort_values()
print(coef)
# Out:
# make_toyota               -787.521627
# fuel-system_spdi          -717.837561
# make_mitsubishi           -688.541458
# make_volkswagen           -682.127329
# drive-wheels_fwd          -655.744952
# aspiration_std            -621.304652
# engine-type_l             -494.187852
# make_peugot               -494.187852
# make_subaru               -468.102387
# engine-type_ohcf          -468.102387
# make_dodge                -390.778143
# make_plymouth             -381.403048
# body-style_wagon          -380.271007
# fuel-system_2bbl          -366.420593
# fuel-system_mfi           -353.627877
# fuel-type_gas             -341.382340
# make_nissan               -210.228908
# drive-wheels_4wd          -194.312343
# body-style_hatchback      -165.127720
# fuel-system_1bbl          -155.856903
# make_mazda                -111.887975
# city-mpg                   -65.072905
# highway-mpg                -64.093394
# num-of-doors_two           -50.047351
# body-style_hardtop         -49.166924
# height                      -0.610423
# peak-rpm                    -0.026700
# engine-location_front        0.000000
# make_porsche                 0.000000
# curb-weight                  1.024235
# symboling                    4.252210
# horsepower                  10.544289
# stroke                      10.962404
# engine-size                 14.086319
# compression-ratio           19.628907
# length                      29.349914
# num-of-doors_four           50.047351
# make_honda                  67.963149
# wheel-base                  77.522224
# make_chevrolet             140.432797
# body-style_sedan           165.958272
# engine-type_ohc            168.711747
# bore                       214.004217
# engine-type_dohc           264.982128
# width                      265.650907
# engine-type_ohcv           271.883245
# fuel-system_idi            341.382340
# fuel-type_diesel           341.382340
# fuel-system_mpfi           383.298987
# aspiration_turbo           621.304652
# num-of-cylinders           634.372203
# make_volvo                 660.281836
# make_saab                  727.085278
# drive-wheels_rwd           782.187454
# make_audi                 1543.560902
# make_bmw                  2143.002494
# make_mercedes-benz        4332.496928
# make_jaguar               4610.985158
# body-style_convertible    4632.853499
# dtype: float64

# %%
y_predict = ridge_model.predict(x_test)

# %%
pylab.rcParams['figure.figsize']=(15, 6)

plt.plot(y_predict, label='Predicted')
plt.plot(y_test.values, label='Actual')
plt.ylabel('Price')

plt.legend()
plt.show()

# %%
r_square = ridge_model.score(x_test, y_test)
r_square
# Out:
# 0.8647551519806755

# %%
ridge_model_mse = mean_squared_error(y_predict, y_test)
math.sqrt(ridge_model_mse)
# Out:
# 2262.494504195845
