# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading https://files.pythonhosted.org/packages/74/41/b01f308ca4a22c8c368ed4ee80ef5318efe2f221cd0024a3a0ee9df6a94d/opencv_python-4.1.2.30-cp37-cp37m-win_amd64.whl (33.0MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.16.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.1.2.30

# %%
import cv2

# %%
imagePath= 'dog.jpg'
image= cv2.imread(imagePath)

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %%
image.shape
# Out:
# (194, 259, 3)

# %%
image
# Out:
# array([[[ 28,  78,  60],
#         [ 29,  79,  61],
#         [ 29,  79,  61],
#         ...,
#         [ 10,  67,  58],
#         [ 10,  67,  58],
#         [ 10,  67,  58]],
#
#        [[ 29,  79,  61],
#         [ 29,  79,  61],
#         [ 29,  79,  61],
#         ...,
#         [ 10,  67,  58],
#         [ 10,  67,  58],
#         [ 10,  67,  58]],
#
#        [[ 29,  79,  61],
#         [ 29,  79,  61],
#         [ 30,  80,  62],
#         ...,
#         [ 10,  67,  58],
#         [ 10,  67,  58],
#         [ 10,  67,  58]],
#
#        ...,
#
#        [[ 84, 144, 126],
#         [ 91, 153, 135],
#         [ 91, 151, 133],
#         ...,
#         [ 60, 131, 104],
#         [ 54, 128, 100],
#         [ 49, 123,  95]],
#
#        [[ 61, 123, 105],
#         [ 68, 132, 113],
#         [ 78, 140, 122],
#         ...,
#         [ 60, 128, 103],
#         [ 58, 129, 103],
#         [ 58, 129, 103]],
#
#        [[ 60, 124, 105],
#         [ 68, 132, 113],
#         [ 77, 141, 122],
#         ...,
#         [ 60, 128, 103],
#         [ 58, 129, 103],
#         [ 58, 129, 103]]], dtype=uint8)

# %%
image[0][0]
# Out:
# array([28, 78, 60], dtype=uint8)

# %%
size=(32, 32)

resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[ 31,  81,  63],
#         [ 25,  77,  53],
#         [ 17,  69,  46],
#         ...,
#         [  8,  71,  56],
#         [  8,  70,  58],
#         [ 14,  70,  59]],
#
#        [[ 31,  86,  67],
#         [ 25,  82,  57],
#         [ 24,  76,  52],
#         ...,
#         [  7,  62,  51],
#         [  8,  66,  56],
#         [  9,  69,  58]],
#
#        [[ 31,  89,  69],
#         [ 30,  89,  65],
#         [ 29,  82,  61],
#         ...,
#         [  6,  53,  45],
#         [  6,  59,  49],
#         [  5,  65,  54]],
#
#        ...,
#
#        [[ 88, 149, 131],
#         [ 71, 137, 118],
#         [113, 162, 148],
#         ...,
#         [ 67, 137, 106],
#         [ 87, 139, 111],
#         [ 79, 134, 110]],
#
#        [[ 85, 146, 128],
#         [ 72, 138, 119],
#         [ 83, 143, 123],
#         ...,
#         [ 80, 142, 112],
#         [ 99, 137, 111],
#         [ 88, 137, 113]],
#
#        [[ 77, 139, 121],
#         [ 76, 142, 123],
#         [ 73, 144, 119],
#         ...,
#         [ 87, 145, 116],
#         [100, 155, 127],
#         [ 66, 136, 109]]], dtype=uint8)

# %%
resized_flattened_image_feature_vector=resized_image_feature_vector.flatten()

# %%
resized_flattened_image_feature_vector
# Out:
# array([ 31,  81,  63, ...,  66, 136, 109], dtype=uint8)

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale=cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (194, 259)

# %%
image_grayscale
# Out:
# array([[ 67,  68,  68, ...,  58,  58,  58],
#        [ 68,  68,  68, ...,  58,  58,  58],
#        [ 68,  68,  69, ...,  58,  58,  58],
#        ...,
#        [132, 141, 139, ..., 115, 111, 106],
#        [111, 119, 128, ..., 113, 113, 113],
#        [111, 119, 128, ..., 113, 113, 113]], dtype=uint8)

# %%
import numpy as np

expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)
expanded_image_grayscale.shape
# Out:
# (194, 259, 1)

# %%
expanded_image_grayscale
# Out:
# array([[[ 67],
#         [ 68],
#         [ 68],
#         ...,
#         [ 58],
#         [ 58],
#         [ 58]],
#
#        [[ 68],
#         [ 68],
#         [ 68],
#         ...,
#         [ 58],
#         [ 58],
#         [ 58]],
#
#        [[ 68],
#         [ 68],
#         [ 69],
#         ...,
#         [ 58],
#         [ 58],
#         [ 58]],
#
#        ...,
#
#        [[132],
#         [141],
#         [139],
#         ...,
#         [115],
#         [111],
#         [106]],
#
#        [[111],
#         [119],
#         [128],
#         ...,
#         [113],
#         [113],
#         [113]],
#
#        [[111],
#         [119],
#         [128],
#         ...,
#         [113],
#         [113],
#         [113]]], dtype=uint8)
