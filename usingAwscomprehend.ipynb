# %%
import boto3
import json
#service_name, region_name=None, api_version=None,
#use_ssl=True, verify=None, endpoint_url=None, aws_access_key_id=None, aws_secret_access_key=None,
#aws_session_token=None, config=None

comprehend = boto3.client(service_name='comprehend', region_name='us-east-1',aws_access_key_id='AKIAIPP4VSD3RF4ELIYA', aws_secret_access_key='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')
text = "It is raining today in Seattle"

print('Calling DetectEntities')
print(json.dumps(comprehend.detect_entities(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectEntities\n')





comprehend = boto3.client(service_name='comprehend', region_name='us-east-1')
                
text = "It is raining today in Seattle"

print('Calling DetectKeyPhrases')
print(json.dumps(comprehend.detect_key_phrases(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
print('End of DetectKeyPhrases\n')
# Out:
# Calling DetectEntities
# {
#     "Entities": [
#         {
#             "BeginOffset": 14,
#             "EndOffset": 19,
#             "Score": 0.9784814119338989,
#             "Text": "today",
#             "Type": "DATE"
#         },
#         {
#             "BeginOffset": 23,
#             "EndOffset": 30,
#             "Score": 0.9954556226730347,
#             "Text": "Seattle",
#             "Type": "LOCATION"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "200",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Wed, 07 Aug 2019 16:48:42 GMT",
#             "x-amzn-requestid": "0f8d0980-7283-4267-81e1-d1c453b8f128"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "0f8d0980-7283-4267-81e1-d1c453b8f128",
#         "RetryAttempts": 0
#     }
# }
# End of DetectEntities
#
# Calling DetectKeyPhrases
# {
#     "KeyPhrases": [
#         {
# ...
